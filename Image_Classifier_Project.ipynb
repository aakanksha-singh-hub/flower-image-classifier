# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/"
# Out:
# '20240828_125732 (1).jpg'
# '20240828_125732 (2).jpg'
#  20240828_125732.jpg
# '20240828_125742 (1).jpg'
# '20240828_125742 (2).jpg'
#  20240828_125742.jpg
# '20240828_183642 (1).jpg'
# '20240828_183642 (2).jpg'
#  20240828_183642.jpg
# '20240828_183646 (1).jpg'
# '20240828_183646 (2).jpg'
#  20240828_183646.jpg
# '20240828_183722 (1).jpg'
# '20240828_183722 (2).jpg'
#  20240828_183722.jpg
# '20240828_183806 (1).jpg'
# '20240828_183806 (2).jpg'
#  20240828_183806.jpg
#  20240828_190738.jpg
#  20240828_200432.jpg
#  AadharCard_AakankshaSingh.pdf
#  aakanksha.singh0205@gmail.com.png
# 'AAKANKSHA SINGH_1151452130005_CBSE.pdf'
# 'AakankshaSingh_Cover Letter for KJSCE CodeCell 24-25.pdf'
# 'Aakanksha Singh.gdoc'
#  AakankshaSingh.jpeg
#  AakankshaSingh.png
# 'AakankshaSingh_Resume (1).pdf'
#  AakankshaSingh_Resume.pdf
# 'AakankshaSingh_Write Right Assignment.gdoc'
#  aipnd-project.zip
# 'A magical and indelible trip to Rajasthan.gdoc'
#  AnitaB.jpg
#  CancelledCheque_AakankshaSingh.pdf
#  certificate.pdf
#  Certification.pdf
#  Checkers.gdoc
#  Classroom
# 'Codecell Brochure.pdf'
#  Codecell.gdoc
# 'Colab Notebooks'
# 'Company-wise Problems_Anshul WE.gsheet'
#  Conclusion:.gdoc
# "copy-crackathon'24.gsheet"
#  CoverLetter_AakankshaSingh.gdoc
# 'CP - Tut.gdoc'
# 'Cwc pics'
#  Datathon.gdoc
#  DESIS.gdoc
#  DJI_20240828_163556_359_video.mp4
#  ETicket_30thJune.pdf
#  Export.png
#  expt2.gdoc
# 'Flight tickets status_AakankshaSingh.pdf'
#  FY_co-curriculars_AakankshaSingh_16010123004.gdoc
# 'GDSC Lead application.gdoc'
# 'Global Hiring Trends.gdoc'
# 'Google Women Techmakers.gdoc'
# 'Hackathon-Secure Medical Records Web App .gdoc'
#  Hacks.gdoc
# 'IICPC Summer Camp 2024 Certificate.png'
# 'Immediate consequences of increasing Pollution - Aakanksha .gdoc'
# 'KJSSE CTF 2.0.gdoc'
#  LinkedIn.gdoc
# 'LinkedIn Post.gdoc'
# 'Linkedin + Resume.gdoc'
#  Marketing.gdoc
#  Mastermind.gdoc
# 'ML - Checkers.gdoc'
#  nutanix_essay.gdoc
# 'PROBLEM STATEMENTS FOR II YEAR (2023 BATCH) MINI PROJECT.gsheet'
#  Projects.gdoc
#  resume.gdoc
# "Scholarships'24.gdoc"
#  shefi.jpg
#  SheFiSeason11.png
#  SIH_PS.gdoc
# 'Skincare Recommendations.gdoc'
# 'stock span question.gdoc'
# 'SuperMind Hackathon.gdoc'
# 'SWE TO PM.gdoc'
# 'Team Silk Road.gdoc'
# "The annoying A's🪩✨💛.gform"
# 'The annoying A'\''s🪩✨💛 (Responses).gsheet'
# 'Time&Space_Complexity.gdoc'
# 'Udacity AWS Scholar.jpg'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document.gdoc'
# 'Untitled spreadsheet.gsheet'
#  WE.gdoc
# 'WE Scholar.gdoc'
#  WEScholar.jpg
# 'WhatsApp Image 2024-05-27 at 23.47.40.jpeg'
# 'WhatsApp Image 2025-01-25 at 00.17.12.jpeg'
# 'Write Right.gdoc'

# %%
# !unzip "/content/drive/My Drive/aipnd-project.zip" -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/aipnd-project/flower_data/train/50/image_06559.jpg
#   inflating: /content/aipnd-project/flower_data/train/50/image_06560.jpg
#   inflating: /content/aipnd-project/flower_data/train/50/image_06561.jpg
#   inflating: /content/aipnd-project/flower_data/train/50/image_06563.jpg
#   inflating: /content/aipnd-project/flower_data/train/50/image_06564.jpg
#   inflating: /content/aipnd-project/flower_data/train/50/image_06565.jpg
#   inflating: /content/aipnd-project/flower_data/train/50/image_06566.jpg
#   inflating: /content/aipnd-project/flower_data/train/50/image_06567.jpg
#   inflating: /content/aipnd-project/flower_data/train/50/image_06568.jpg
#   inflating: /content/aipnd-project/flower_data/train/50/image_06569.jpg
#   inflating: /content/aipnd-project/flower_data/train/50/image_06570.jpg
#    creating: /content/aipnd-project/flower_data/train/51/
#   inflating: /content/aipnd-project/flower_data/train/51/image_01317.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01318.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01319.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01320.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01321.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01323.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01324.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01325.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01327.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01329.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01330.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01331.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01332.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01333.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01334.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01336.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01337.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01338.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01339.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01341.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01342.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01343.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01344.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01345.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01347.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01348.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01349.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01350.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01351.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01353.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01355.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01356.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01357.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01358.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01359.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01360.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01361.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01364.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01365.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01366.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01367.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01368.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01369.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01371.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01372.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01373.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01374.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01375.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01376.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01377.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01378.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01379.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01380.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01381.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01382.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01383.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01384.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01385.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01386.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01387.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01390.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01392.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01393.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01394.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01395.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01396.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01397.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01398.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01399.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01400.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01401.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01402.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01403.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01404.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01405.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01408.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01409.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01410.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01411.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01412.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01413.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01415.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01416.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01417.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01418.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01420.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01421.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01422.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01423.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01424.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01426.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01427.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01428.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01429.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01430.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01431.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01432.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01433.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01434.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01435.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01436.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01437.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01438.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01440.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01441.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01442.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01443.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01444.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01445.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01446.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01447.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01448.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01449.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01450.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01451.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01452.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01453.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01454.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01455.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01456.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01458.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01460.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01461.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01462.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01463.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01464.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01465.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01466.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01467.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01470.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01471.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01472.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01475.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01476.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01477.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01478.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01479.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01480.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01481.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01482.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01483.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01484.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01485.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01486.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01487.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01488.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01489.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_01490.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03913.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03914.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03915.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03918.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03919.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03920.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03921.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03922.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03923.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03924.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03925.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03928.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03929.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03930.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03931.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03932.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03934.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03935.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03936.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03940.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03941.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03942.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03944.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03945.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03947.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03948.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03949.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03950.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03952.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03953.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03955.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03956.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03957.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03958.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03959.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03962.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03963.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03964.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03965.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03966.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03967.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03969.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03970.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03971.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03972.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03976.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03977.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03978.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03979.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03981.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03982.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03983.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03987.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03988.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03990.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03991.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03992.jpg
#   inflating: /content/aipnd-project/flower_data/train/51/image_03993.jpg
#    creating: /content/aipnd-project/flower_data/train/52/
#   inflating: /content/aipnd-project/flower_data/train/52/image_04159.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04161.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04162.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04164.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04165.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04166.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04170.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04171.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04174.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04175.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04176.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04177.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04178.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04179.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04180.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04183.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04184.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04185.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04186.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04187.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04188.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04189.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04190.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04192.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04193.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04194.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04195.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04196.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04197.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04198.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04199.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04201.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04202.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04203.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04204.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04205.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04206.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04208.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04209.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04210.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04211.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04212.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04213.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04214.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04216.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04217.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04218.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04219.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04220.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04222.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04223.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04224.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04226.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04227.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04228.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04229.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04230.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04231.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04232.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04233.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04234.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04236.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04237.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04239.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04241.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04242.jpg
#   inflating: /content/aipnd-project/flower_data/train/52/image_04243.jpg
#    creating: /content/aipnd-project/flower_data/train/53/
#   inflating: /content/aipnd-project/flower_data/train/53/image_03641.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03642.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03643.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03644.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03646.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03647.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03648.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03650.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03651.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03657.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03658.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03659.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03660.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03661.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03663.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03664.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03665.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03666.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03671.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03673.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03674.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03675.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03676.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03678.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03679.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03680.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03681.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03682.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03683.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03684.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03685.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03686.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03687.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03688.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03690.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03691.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03692.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03694.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03695.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03696.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03697.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03698.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03699.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03700.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03701.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03703.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03704.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03705.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03706.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03707.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03708.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03709.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03710.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03711.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03713.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03715.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03716.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03719.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03720.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03721.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03722.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03723.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03725.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03726.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03727.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03728.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03729.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03730.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03731.jpg
#   inflating: /content/aipnd-project/flower_data/train/53/image_03732.jpg
#    creating: /content/aipnd-project/flower_data/train/54/
#   inflating: /content/aipnd-project/flower_data/train/54/image_05399.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05400.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05401.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05403.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05404.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05405.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05407.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05408.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05409.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05410.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05412.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05414.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05416.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05418.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05419.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05420.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05421.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05422.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05423.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05424.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05427.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05428.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05429.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05431.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05432.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05433.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05434.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05435.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05436.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05437.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05438.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05439.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05441.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05442.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05443.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05444.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05445.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05446.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05447.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05448.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05450.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05454.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05455.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05456.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05457.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05458.jpg
#   inflating: /content/aipnd-project/flower_data/train/54/image_05459.jpg
#    creating: /content/aipnd-project/flower_data/train/55/
#   inflating: /content/aipnd-project/flower_data/train/55/image_04697.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04698.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04699.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04700.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04703.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04704.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04705.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04706.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04708.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04709.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04710.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04711.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04712.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04713.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04714.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04715.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04716.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04717.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04718.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04719.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04721.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04723.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04724.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04725.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04726.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04727.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04728.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04729.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04730.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04732.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04735.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04736.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04737.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04738.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04741.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04743.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04744.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04745.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04746.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04748.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04749.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04750.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04751.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04752.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04754.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04755.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04756.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04757.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04758.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04759.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04761.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04762.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04763.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04764.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04765.jpg
#   inflating: /content/aipnd-project/flower_data/train/55/image_04766.jpg
#    creating: /content/aipnd-project/flower_data/train/56/
#   inflating: /content/aipnd-project/flower_data/train/56/image_02753.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02754.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02755.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02756.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02757.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02758.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02759.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02760.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02761.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02762.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02763.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02764.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02765.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02766.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02767.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02768.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02770.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02774.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02775.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02776.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02777.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02778.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02780.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02781.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02782.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02783.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02784.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02786.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02787.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02789.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02790.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02791.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02793.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02794.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02795.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02796.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02797.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02798.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02799.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02800.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02801.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02802.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02803.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02804.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02806.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02807.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02809.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02810.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02811.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02812.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02813.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02814.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02815.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02816.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02817.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02818.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02819.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02820.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02822.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02823.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02824.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02826.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02827.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02828.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02829.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02830.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02831.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02832.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02833.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02834.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02835.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02836.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02837.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02838.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02839.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02840.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02842.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02843.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02845.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02846.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02847.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02848.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02850.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02851.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02852.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02853.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02854.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02855.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02856.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02859.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02860.jpg
#   inflating: /content/aipnd-project/flower_data/train/56/image_02861.jpg
#    creating: /content/aipnd-project/flower_data/train/57/
#   inflating: /content/aipnd-project/flower_data/train/57/image_07235.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07236.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07237.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07238.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07240.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07243.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07244.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07245.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07246.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07248.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07249.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07251.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07252.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07253.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07256.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07257.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07258.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07259.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07260.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07261.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07263.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07264.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_07265.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08118.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08119.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08120.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08121.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08122.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08123.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08124.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08125.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08126.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08128.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08130.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08131.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08132.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08135.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08136.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08137.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08138.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08139.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08140.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08141.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08142.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08143.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08146.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08147.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08148.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08149.jpg
#   inflating: /content/aipnd-project/flower_data/train/57/image_08150.jpg
#    creating: /content/aipnd-project/flower_data/train/58/
#   inflating: /content/aipnd-project/flower_data/train/58/image_02639.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02640.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02641.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02643.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02644.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02645.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02646.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02647.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02648.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02650.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02651.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02652.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02654.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02655.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02657.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02658.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02659.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02660.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02661.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02662.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02664.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02665.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02666.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02667.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02668.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02669.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02670.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02671.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02673.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02674.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02678.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02679.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02680.jpg
#   inflating: /content/aipnd-project/flower_data/train/58/image_02682.jpg
# ...
#   inflating: /content/aipnd-project/flower_data/valid/80/image_02050.jpg
#    creating: /content/aipnd-project/flower_data/valid/81/
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00784.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00809.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00820.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00848.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00853.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00859.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00860.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00863.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00892.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00893.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00895.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00896.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00903.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00904.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00909.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00914.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00919.jpg
#   inflating: /content/aipnd-project/flower_data/valid/81/image_00920.jpg
#    creating: /content/aipnd-project/flower_data/valid/82/
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01592.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01596.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01625.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01640.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01643.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01649.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01658.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01659.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01671.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01683.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01690.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01691.jpg
#   inflating: /content/aipnd-project/flower_data/valid/82/image_01693.jpg
#    creating: /content/aipnd-project/flower_data/valid/83/
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01697.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01701.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01703.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01712.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01739.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01747.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01765.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01766.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01769.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01780.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01787.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01811.jpg
#   inflating: /content/aipnd-project/flower_data/valid/83/image_01817.jpg
#    creating: /content/aipnd-project/flower_data/valid/84/
#   inflating: /content/aipnd-project/flower_data/valid/84/image_02567.jpg
#   inflating: /content/aipnd-project/flower_data/valid/84/image_02574.jpg
#   inflating: /content/aipnd-project/flower_data/valid/84/image_02582.jpg
#   inflating: /content/aipnd-project/flower_data/valid/84/image_02591.jpg
#   inflating: /content/aipnd-project/flower_data/valid/84/image_02598.jpg
#   inflating: /content/aipnd-project/flower_data/valid/84/image_02604.jpg
#   inflating: /content/aipnd-project/flower_data/valid/84/image_02610.jpg
#   inflating: /content/aipnd-project/flower_data/valid/84/image_02621.jpg
#   inflating: /content/aipnd-project/flower_data/valid/84/image_02635.jpg
#   inflating: /content/aipnd-project/flower_data/valid/84/image_02637.jpg
#    creating: /content/aipnd-project/flower_data/valid/85/
#   inflating: /content/aipnd-project/flower_data/valid/85/image_04799.jpg
#   inflating: /content/aipnd-project/flower_data/valid/85/image_04804.jpg
#   inflating: /content/aipnd-project/flower_data/valid/85/image_04809.jpg
#   inflating: /content/aipnd-project/flower_data/valid/85/image_04817.jpg
#   inflating: /content/aipnd-project/flower_data/valid/85/image_04818.jpg
#    creating: /content/aipnd-project/flower_data/valid/86/
#   inflating: /content/aipnd-project/flower_data/valid/86/image_02887.jpg
#   inflating: /content/aipnd-project/flower_data/valid/86/image_02891.jpg
#   inflating: /content/aipnd-project/flower_data/valid/86/image_02901.jpg
#   inflating: /content/aipnd-project/flower_data/valid/86/image_02906.jpg
#   inflating: /content/aipnd-project/flower_data/valid/86/image_02909.jpg
#    creating: /content/aipnd-project/flower_data/valid/87/
#   inflating: /content/aipnd-project/flower_data/valid/87/image_05484.jpg
#   inflating: /content/aipnd-project/flower_data/valid/87/image_05487.jpg
#   inflating: /content/aipnd-project/flower_data/valid/87/image_05502.jpg
#   inflating: /content/aipnd-project/flower_data/valid/87/image_05507.jpg
#   inflating: /content/aipnd-project/flower_data/valid/87/image_05508.jpg
#   inflating: /content/aipnd-project/flower_data/valid/87/image_05520.jpg
#    creating: /content/aipnd-project/flower_data/valid/88/
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00459.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00461.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00489.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00502.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00508.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00509.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00512.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00516.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00518.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00531.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00533.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00539.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00542.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00544.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00545.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00546.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00547.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00554.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00556.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00574.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00577.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00585.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00593.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00595.jpg
#   inflating: /content/aipnd-project/flower_data/valid/88/image_00597.jpg
#    creating: /content/aipnd-project/flower_data/valid/89/
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00623.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00624.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00627.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00640.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00652.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00691.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00692.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00696.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00730.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00741.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00746.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00749.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00752.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00759.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00763.jpg
#   inflating: /content/aipnd-project/flower_data/valid/89/image_00764.jpg
#    creating: /content/aipnd-project/flower_data/valid/9/
#   inflating: /content/aipnd-project/flower_data/valid/9/image_06398.jpg
#   inflating: /content/aipnd-project/flower_data/valid/9/image_06414.jpg
#   inflating: /content/aipnd-project/flower_data/valid/9/image_06420.jpg
#    creating: /content/aipnd-project/flower_data/valid/90/
#   inflating: /content/aipnd-project/flower_data/valid/90/image_04402.jpg
#   inflating: /content/aipnd-project/flower_data/valid/90/image_04403.jpg
#    creating: /content/aipnd-project/flower_data/valid/91/
#   inflating: /content/aipnd-project/flower_data/valid/91/image_04829.jpg
#   inflating: /content/aipnd-project/flower_data/valid/91/image_04835.jpg
#   inflating: /content/aipnd-project/flower_data/valid/91/image_04843.jpg
#   inflating: /content/aipnd-project/flower_data/valid/91/image_04844.jpg
#   inflating: /content/aipnd-project/flower_data/valid/91/image_04848.jpg
#   inflating: /content/aipnd-project/flower_data/valid/91/image_04854.jpg
#   inflating: /content/aipnd-project/flower_data/valid/91/image_04872.jpg
#   inflating: /content/aipnd-project/flower_data/valid/91/image_04878.jpg
#   inflating: /content/aipnd-project/flower_data/valid/91/image_08059.jpg
#    creating: /content/aipnd-project/flower_data/valid/92/
#   inflating: /content/aipnd-project/flower_data/valid/92/image_03063.jpg
#   inflating: /content/aipnd-project/flower_data/valid/92/image_03065.jpg
#    creating: /content/aipnd-project/flower_data/valid/93/
#   inflating: /content/aipnd-project/flower_data/valid/93/image_06024.jpg
#   inflating: /content/aipnd-project/flower_data/valid/93/image_06044.jpg
#   inflating: /content/aipnd-project/flower_data/valid/93/image_06048.jpg
#   inflating: /content/aipnd-project/flower_data/valid/93/image_07302.jpg
#   inflating: /content/aipnd-project/flower_data/valid/93/image_07303.jpg
#   inflating: /content/aipnd-project/flower_data/valid/93/image_08113.jpg
#    creating: /content/aipnd-project/flower_data/valid/94/
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07317.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07325.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07360.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07372.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07381.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07382.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07385.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07392.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07393.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07408.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07418.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07428.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07435.jpg
#   inflating: /content/aipnd-project/flower_data/valid/94/image_07449.jpg
#    creating: /content/aipnd-project/flower_data/valid/95/
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07471.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07475.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07484.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07485.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07502.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07510.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07512.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07513.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07575.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07580.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07581.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07585.jpg
#   inflating: /content/aipnd-project/flower_data/valid/95/image_07588.jpg
#    creating: /content/aipnd-project/flower_data/valid/96/
#   inflating: /content/aipnd-project/flower_data/valid/96/image_07605.jpg
#   inflating: /content/aipnd-project/flower_data/valid/96/image_07609.jpg
#   inflating: /content/aipnd-project/flower_data/valid/96/image_07613.jpg
#   inflating: /content/aipnd-project/flower_data/valid/96/image_07653.jpg
#   inflating: /content/aipnd-project/flower_data/valid/96/image_07656.jpg
#   inflating: /content/aipnd-project/flower_data/valid/96/image_07658.jpg
#   inflating: /content/aipnd-project/flower_data/valid/96/image_07662.jpg
#   inflating: /content/aipnd-project/flower_data/valid/96/image_07669.jpg
#   inflating: /content/aipnd-project/flower_data/valid/96/image_07670.jpg
#   inflating: /content/aipnd-project/flower_data/valid/96/image_07677.jpg
#    creating: /content/aipnd-project/flower_data/valid/97/
#   inflating: /content/aipnd-project/flower_data/valid/97/image_07697.jpg
#   inflating: /content/aipnd-project/flower_data/valid/97/image_07699.jpg
#   inflating: /content/aipnd-project/flower_data/valid/97/image_07718.jpg
#   inflating: /content/aipnd-project/flower_data/valid/97/image_07723.jpg
#   inflating: /content/aipnd-project/flower_data/valid/97/image_07727.jpg
#   inflating: /content/aipnd-project/flower_data/valid/97/image_07739.jpg
#   inflating: /content/aipnd-project/flower_data/valid/97/image_07745.jpg
#    creating: /content/aipnd-project/flower_data/valid/98/
#   inflating: /content/aipnd-project/flower_data/valid/98/image_07757.jpg
#   inflating: /content/aipnd-project/flower_data/valid/98/image_07764.jpg
#   inflating: /content/aipnd-project/flower_data/valid/98/image_07766.jpg
#   inflating: /content/aipnd-project/flower_data/valid/98/image_07769.jpg
#   inflating: /content/aipnd-project/flower_data/valid/98/image_07778.jpg
#   inflating: /content/aipnd-project/flower_data/valid/98/image_07792.jpg
#   inflating: /content/aipnd-project/flower_data/valid/98/image_07796.jpg
#   inflating: /content/aipnd-project/flower_data/valid/98/image_07810.jpg
#   inflating: /content/aipnd-project/flower_data/valid/98/image_07820.jpg
#   inflating: /content/aipnd-project/flower_data/valid/98/image_07827.jpg
#    creating: /content/aipnd-project/flower_data/valid/99/
#   inflating: /content/aipnd-project/flower_data/valid/99/image_07860.jpg
#   inflating: /content/aipnd-project/flower_data/valid/99/image_07862.jpg
#   inflating: /content/aipnd-project/flower_data/valid/99/image_07869.jpg
#   inflating: /content/aipnd-project/flower_data/valid/99/image_07873.jpg
#   inflating: /content/aipnd-project/flower_data/valid/99/image_07875.jpg
#   inflating: /content/aipnd-project/flower_data/valid/99/image_08063.jpg
#   inflating: /content/aipnd-project/Image Classifier Project.ipynb
#   inflating: /content/aipnd-project/LICENSE
#   inflating: /content/aipnd-project/predict.py
#   inflating: /content/aipnd-project/README.md
#   inflating: /content/aipnd-project/train.py

# %%
# %cd /content/aipnd-project/
# Out:
# /content/aipnd-project

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import DataLoader, Dataset
from torchvision.datasets import ImageFolder
from collections import OrderedDict

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import json
import os

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

data_dir = 'flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(30),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# Load datasets with ImageFolder
image_datasets = {
    'train': ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': ImageFolder(test_dir, transform=data_transforms['test'])
}

dataloaders = {
    'train': DataLoader(image_datasets['train'], batch_size=64, shuffle=True),
    'valid': DataLoader(image_datasets['valid'], batch_size=64, shuffle=False),
    'test': DataLoader(image_datasets['test'], batch_size=64, shuffle=False)
}

class_to_idx = image_datasets['train'].class_to_idx

# %%
print(os.listdir("/content/aipnd-project"))  # Adjust path if needed
# Out:
# ['cat_to_name.json', 'predict.py', 'checkpoint.pth', '.github', 'README.md', 'CODEOWNERS', 'train.py', 'assets', 'LICENSE', '.git', '.gitignore', 'flower_data', 'Image Classifier Project.ipynb']

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

json_path = "/content/aipnd-project/cat_to_name.json"
with open(json_path, "r") as f:
    cat_to_name = json.load(f)

print(cat_to_name)
# Out:
# {'21': 'fire lily', '3': 'canterbury bells', '45': 'bolero deep blue', '1': 'pink primrose', '34': 'mexican aster', '27': 'prince of wales feathers', '7': 'moon orchid', '16': 'globe-flower', '25': 'grape hyacinth', '26': 'corn poppy', '79': 'toad lily', '39': 'siam tulip', '24': 'red ginger', '67': 'spring crocus', '35': 'alpine sea holly', '32': 'garden phlox', '10': 'globe thistle', '6': 'tiger lily', '93': 'ball moss', '33': 'love in the mist', '9': 'monkshood', '102': 'blackberry lily', '14': 'spear thistle', '19': 'balloon flower', '100': 'blanket flower', '13': 'king protea', '49': 'oxeye daisy', '15': 'yellow iris', '61': 'cautleya spicata', '31': 'carnation', '64': 'silverbush', '68': 'bearded iris', '63': 'black-eyed susan', '69': 'windflower', '62': 'japanese anemone', '20': 'giant white arum lily', '38': 'great masterwort', '4': 'sweet pea', '86': 'tree mallow', '101': 'trumpet creeper', '42': 'daffodil', '22': 'pincushion flower', '2': 'hard-leaved pocket orchid', '54': 'sunflower', '66': 'osteospermum', '70': 'tree poppy', '85': 'desert-rose', '99': 'bromelia', '87': 'magnolia', '5': 'english marigold', '92': 'bee balm', '28': 'stemless gentian', '97': 'mallow', '57': 'gaura', '40': 'lenten rose', '47': 'marigold', '59': 'orange dahlia', '48': 'buttercup', '55': 'pelargonium', '36': 'ruby-lipped cattleya', '91': 'hippeastrum', '29': 'artichoke', '71': 'gazania', '90': 'canna lily', '18': 'peruvian lily', '98': 'mexican petunia', '8': 'bird of paradise', '30': 'sweet william', '17': 'purple coneflower', '52': 'wild pansy', '84': 'columbine', '12': "colt's foot", '11': 'snapdragon', '96': 'camellia', '23': 'fritillary', '50': 'common dandelion', '44': 'poinsettia', '53': 'primula', '72': 'azalea', '65': 'californian poppy', '80': 'anthurium', '76': 'morning glory', '37': 'cape flower', '56': 'bishop of llandaff', '60': 'pink-yellow dahlia', '82': 'clematis', '58': 'geranium', '75': 'thorn apple', '41': 'barbeton daisy', '95': 'bougainvillea', '43': 'sword lily', '83': 'hibiscus', '78': 'lotus lotus', '88': 'cyclamen', '94': 'foxglove', '81': 'frangipani', '74': 'rose', '89': 'watercress', '73': 'water lily', '46': 'wallflower', '77': 'passion flower', '51': 'petunia'}

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models

# Load pre-trained VGG16
model = models.vgg16(pretrained=True)

for param in model.features.parameters():
    param.requires_grad = False

# %%
classifier = nn.Sequential(
    nn.Linear(25088, 4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096, 1024),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(1024, 102),  # 102 output classes (flowers)
    nn.LogSoftmax(dim=1)
)

model.classifier = classifier

# %%
criterion = nn.NLLLoss()  # Negative Log Likelihood Loss for classification
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=1024, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=1024, out_features=102, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )

# %%
epochs = 5
train_loader = dataloaders['train']
valid_loader = dataloaders['valid']

for epoch in range(epochs):
    running_loss = 0
    model.train()  # Set model to training mode

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        output = model(inputs)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    # Validation Phase
    model.eval()  # Set model to evaluation mode
    valid_loss = 0
    accuracy = 0

    with torch.no_grad():
        for inputs, labels in valid_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            output = model(inputs)
            loss = criterion(output, labels)
            valid_loss += loss.item()

            # Calculate Accuracy
            preds = torch.exp(output).argmax(dim=1)
            accuracy += (preds == labels).sum().item()

    print(f"Epoch {epoch+1}/{epochs}.. "
          f"Train loss: {running_loss/len(train_loader):.3f}.. "
          f"Validation loss: {valid_loss/len(valid_loader):.3f}.. "
          f"Validation accuracy: {accuracy/len(valid_loader.dataset):.3f}")
# Out:
# Epoch 1/5.. Train loss: 4.004.. Validation loss: 2.328.. Validation accuracy: 0.424
# Epoch 2/5.. Train loss: 2.684.. Validation loss: 1.693.. Validation accuracy: 0.539
# Epoch 3/5.. Train loss: 2.341.. Validation loss: 1.206.. Validation accuracy: 0.678
# Epoch 4/5.. Train loss: 2.175.. Validation loss: 1.057.. Validation accuracy: 0.708
# Epoch 5/5.. Train loss: 2.072.. Validation loss: 1.011.. Validation accuracy: 0.743

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set

model.eval()
test_loader = dataloaders['test']
criterion = nn.NLLLoss()

test_loss = 0
accuracy = 0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# (WE should disable gradient calculations for faster computation)
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        output = model(inputs)
        loss = criterion(output, labels)
        test_loss += loss.item()

        # Accuracy
        preds = output.argmax(dim=1)
        accuracy += (preds == labels).sum().item()

test_loss /= len(test_loader)
test_accuracy = accuracy / len(test_loader.dataset)

print(f"Test Loss: {test_loss:.3f}")
print(f"Test Accuracy: {test_accuracy:.3f}")
# Out:
# Test Loss: 1.053
# Test Accuracy: 0.720

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint

import torch

model.class_to_idx = image_datasets['train'].class_to_idx
checkpoint = {
    'architecture': 'vgg16',
    'classifier': model.classifier,
    'state_dict': model.state_dict(),
    'class_to_idx': model.class_to_idx,
    'optimizer_state': optimizer.state_dict(),
    'epochs': epochs
}

torch.save(checkpoint, 'checkpoint.pth')
print("Checkpoint saved successfully! YAY")
# Out:
# Checkpoint saved successfully! YAY

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

import torch
import torchvision.models as models
import torch.nn as nn

def load_checkpoint(filepath):
    torch.serialization.add_safe_globals([nn.Sequential])

    checkpoint = torch.load(filepath, weights_only=False, map_location=torch.device("cuda" if torch.cuda.is_available() else "cpu"))


    model = models.vgg16(pretrained=True)
    model.classifier = checkpoint['classifier']
    model.load_state_dict(checkpoint['state_dict'])
    model.class_to_idx = checkpoint['class_to_idx']

    return model

# Load the model
loaded_model = load_checkpoint('checkpoint.pth')
print("Model loaded successfully!YAYY")
# Out:
# Model loaded successfully!YAYY

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
from PIL import Image
import numpy as np
import torch

def process_image(image_path):
    '''Scales, crops, and normalizes a PIL image for a PyTorch model'''

    # Open the image
    image = Image.open(image_path)

    # First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio.
    image.thumbnail((256, 256))

    # Next, Center crop to 224x224
    width, height = image.size
    left = (width - 224) / 2
    top = (height - 224) / 2
    right = (width + 224) / 2
    bottom = (height + 224) / 2
    image = image.crop((left, top, right, bottom))

    # Next, Convert to numpy array
    np_image = np.array(image) / 255.0  # Convert to range 0-1

    # Next, Normalize (subtract mean, divide by std deviation)
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    np_image = (np_image - mean) / std

    # Reorder dimensions
    np_image = np_image.transpose((2, 0, 1))

    return torch.tensor(np_image, dtype=torch.float32)  # Convert to tensor

image_path = "path_to_your_image.jpg"
processed_image = process_image(image_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-e1bb3764285c> in <cell line: 0>()
#      34
#      35 image_path = "path_to_your_image.jpg"
# ---> 36 processed_image = process_image(image_path)
#
# <ipython-input-28-e1bb3764285c> in process_image(image_path)
#       7
#       8     # Open the image
# ----> 9     image = Image.open(image_path)
#      10
#      11     # First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio.
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3463
#    3464     if filename:
# -> 3465         fp = builtins.open(filename, "rb")
#    3466         exclusive_fp = True
#    3467     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path_to_your_image.jpg'

# %%
# %cd /content/aipnd-project/
# Out:
# /content/aipnd-project

# %%
# %cd flower_data
# Out:
# [Errno 2] No such file or directory: 'flower_data'
# /content/aipnd-project/flower_data

# %%
# !find /content/aipnd-project/flower_data/ -name "*.jpg" | head -10
# Out:
# /content/aipnd-project/flower_data/valid/8/image_03342.jpg
# /content/aipnd-project/flower_data/valid/8/image_03330.jpg
# /content/aipnd-project/flower_data/valid/8/image_03349.jpg
# /content/aipnd-project/flower_data/valid/8/image_03366.jpg
# /content/aipnd-project/flower_data/valid/8/image_03313.jpg
# /content/aipnd-project/flower_data/valid/35/image_07004.jpg
# /content/aipnd-project/flower_data/valid/35/image_06977.jpg
# /content/aipnd-project/flower_data/valid/35/image_06978.jpg
# /content/aipnd-project/flower_data/valid/35/image_07005.jpg
# /content/aipnd-project/flower_data/valid/29/image_04099.jpg

# %%
from PIL import Image
import numpy as np
import torch

def process_image(image_path):
    '''Scales, crops, and normalizes a PIL image for a PyTorch model'''

    # Open the image
    image = Image.open(image_path)

    # First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio.
    image.thumbnail((256, 256))

    # Next, Center crop to 224x224
    width, height = image.size
    left = (width - 224) / 2
    top = (height - 224) / 2
    right = (width + 224) / 2
    bottom = (height + 224) / 2
    image = image.crop((left, top, right, bottom))

    # Next, Convert to numpy array
    np_image = np.array(image) / 255.0  # Convert to range 0-1

    # Next, Normalize (subtract mean, divide by std deviation)
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    np_image = (np_image - mean) / std

    # Reorder dimensions
    np_image = np_image.transpose((2, 0, 1))

    return torch.tensor(np_image, dtype=torch.float32)  # Convert to tensor

image_path = "/content/aipnd-project/flower_data/valid/8/image_03342.jpg"
processed_image = process_image(image_path)

imshow(processed_image)
plt.show()

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()

    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))

    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)

    ax.imshow(image)

    return ax

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Process the image
image_path = "/content/aipnd-project/flower_data/test/1/image_06743.jpg"  # Change this to an actual image path
processed_image = process_image(image_path)

# Display the processed image
imshow(processed_image)
plt.show()

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
import torch
import numpy as np

def predict(image_path, model, topk=5):
    '''Predict the class (or classes) of an image using a trained deep learning model.'''

    img = process_image(image_path)

    # Ensure the image is a PyTorch tensor
    if not isinstance(img, torch.Tensor):
        img = torch.from_numpy(img)

    img = img.type(torch.FloatTensor)
    img = img.unsqueeze(0)  # Model expects batch dimension

    # Move to the same device as the model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    img = img.to(device)

    model.eval()
    with torch.no_grad():
        output = model(img)

    # Get top-K probabilities and indices
    probs, indices = torch.exp(output).topk(topk)

    probs = probs.cpu().numpy().flatten()
    indices = indices.cpu().numpy().flatten()

    idx_to_class = {val: key for key, val in model.class_to_idx.items()}
    classes = [idx_to_class[i] for i in indices]

    return probs, classes

# %%
probs, classes = predict(image_path, loaded_model)

print("Probabilities:", probs)
print("Classes:", classes)
# Out:
# Probabilities: [0.3772625  0.20800598 0.10109095 0.07386346 0.06118529]
# Classes: ['1', '83', '76', '51', '86']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# Load category-to-name mapping
with open("/content/aipnd-project/cat_to_name.json", "r") as f:
    cat_to_name = json.load(f)

def display_prediction(image_path, model, topk=5):
    '''Display an image along with the top 5 class predictions.'''

    probs, classes = predict(image_path, model, topk=topk)

    class_names = [cat_to_name[str(cls)] for cls in classes]

    img = process_image(image_path)

    if not isinstance(img, torch.Tensor):
        img = torch.from_numpy(img)

    # Display the image
    fig, (ax1, ax2) = plt.subplots(figsize=(6, 9), nrows=2)

    imshow(img, ax=ax1)
    ax1.set_title(class_names[0])
    ax1.axis("off")

    # Bar chart for probabilities
    y_pos = np.arange(len(class_names))
    ax2.barh(y_pos, probs, color="blue")
    ax2.set_yticks(y_pos)
    ax2.set_yticklabels(class_names)
    ax2.invert_yaxis()

    plt.show()

image_path = "/content/aipnd-project/flower_data/test/1/image_06743.jpg"
display_prediction(image_path, loaded_model)
